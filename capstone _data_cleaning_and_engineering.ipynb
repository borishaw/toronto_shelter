# %% [markdown]
# # Capstone - Toronto Shelter Occupancy Prediction

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import warnings
import datetime
import requests
import json
import dateutil.parser
import matplotlib.pyplot as plt
from astral import Astral

# Ignore warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---

# %% [markdown]
# ## Data Clearning & Feature Engineering

# %% [markdown]
# ### Shelter Occupancy Data

# %%
# Getting occupancy data
df_17 = pd.read_csv('data/daily-shelter-occupancy-2017-csv.csv')
df_18 = pd.read_csv('data/daily-shelter-occupancy-2018-csv.csv')
df_19 = pd.read_json('https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/e4cdcaff-7c06-488a-a072-4880fbd84b88')
df = pd.concat([df_17, df_18, df_19])

# %%
# Dropping unuseful columns
df.drop(['_id', 'id'], axis=1, inplace=True)

# %%
# Checking if there are any rows with null or zero value in CAPACITY but non-zero value in OCCUPANCY
for program in df[((df.CAPACITY.isna()) | (df.CAPACITY == 0)) & (df.OCCUPANCY != 0)]['PROGRAM_NAME'].value_counts().index:
    # Assuming the max OCCUPANCY as the CAPACITY
    df.loc[df.PROGRAM_NAME == program, 'CAPACITY'] = df[df.PROGRAM_NAME == program].OCCUPANCY.max()

# %%
# Checking if there are any rows with null or zero values in OCCUPANCY, and drop these rows
df.drop(df[(df.OCCUPANCY == 0) | (df.OCCUPANCY.isna())].index, inplace=True)

# %%
# Calculating occupancy rate
df['OCCUPANCY_RATE'] = df.OCCUPANCY / df.CAPACITY

# Changing data type of CAPACITY column
df.CAPACITY = df.CAPACITY.astype(int)

# Changing data type of OCCUPANCY_DATE
df.OCCUPANCY_DATE = pd.to_datetime(df.OCCUPANCY_DATE)

# %%
# Getting addresses with empty postal codes
missing_postal_code_addresses = df[df.SHELTER_POSTAL_CODE.isna()].SHELTER_ADDRESS.value_counts().index

# Getting correct postal codes from Google Maps
postal_dict = {
    '38 Bathrust St': 'M5V 3W3',
    '67 Adelaide Street East' : 'M5C 1K6', 
    '1673 Kingston Road' : 'M1N 1S6',
    '1651 Sheppard Ave West' : 'M3M 2X4', 
    '129 Peter St' : 'M5V 1X1'
}

# Filling missing postal codes
for address in missing_postal_code_addresses:
    df.loc[df.SHELTER_ADDRESS == address, 'SHELTER_POSTAL_CODE'] = postal_dict[address]

# %%
# Cleaning postal code format

# Remove non-alphanumeric characters
df.SHELTER_POSTAL_CODE = df.SHELTER_POSTAL_CODE.replace('[^a-zA-Z0-9]', '' ,regex=True)

# Separate two components with space
df.SHELTER_POSTAL_CODE = df.SHELTER_POSTAL_CODE.apply(lambda s: s[:3] + ' ' + s[3:])

# Cleaning wrong postal code characters (M2N OE3)
df.loc[df.SHELTER_POSTAL_CODE == 'M2N OE3', 'SHELTER_POSTAL_CODE'] = 'M2N 0E3'

# %%
# Getting shelter location coordinates and sublocalities (i.e. Old Toronto, Scarborough, North York, etc.)
coordinates = []
for postal_code in df.SHELTER_POSTAL_CODE.unique():
    try:
        response = requests.get(
            'https://maps.googleapis.com/maps/api/geocode/json', 
            params = {'address' : postal_code, 'key' : 'AIzaSyA1h6MPEmN3FrIM2Yr3awaU03C6P9iwMCo'})
        result = json.loads(response.content.decode("utf-8"))['results'][0]
        lat = result['geometry']['location']['lat']
        lng = result['geometry']['location']['lng']
        sublocaity = result['address_components'][1]['short_name']
        coordinates.append([postal_code, lat, lng, sublocaity])
    except:
        print(postal_code)

# %%
# Saving shelter coordinate info to a Data Frame
coor_df = pd.DataFrame(coordinates, columns=['SHELTER_POSTAL_CODE', 'lat', 'lng', 'sublocality'])

# %%
# Writing shelter coordinate info to a csv file
coor_df.to_csv('data/shelter_coordinates.csv')

# %%
# A histogram showing that the distribution of shelter capacity
# Most of the shelters have capacities below 200
plt.figure()
plt.xlabel('Capacity')
plt.ylabel('Number of records')
plt.hist(df.CAPACITY, bins=60)
plt.show()

# %% [markdown]
# *Since this project focuses on the shelter occupancy data related homelessness, a judgement call is needed to exclude programs related to new immigrant/refugee settlement.*

# %%
# df[df.PROGRAM_NAME.str.contains('Refugee')].PROGRAM_NAME.unique()
# df[df.PROGRAM_NAME.str.contains('Hotel')].PROGRAM_NAME.unique()
# df[df.PROGRAM_NAME.str.contains('Welcome')].PROGRAM_NAME.unique()
# df[df.PROGRAM_NAME.str.contains('Settlement')].PROGRAM_NAME.unique()

# df[df.FACILITY_NAME.str.contains('Refugee')].FACILITY_NAME.unique()
# df[df.FACILITY_NAME.str.contains('Hotel')].FACILITY_NAME.unique()
# df[df.FACILITY_NAME.str.contains('Welcome')].FACILITY_NAME.unique()
# df[df.FACILITY_NAME.str.contains('Settlement')].FACILITY_NAME.unique()

# df.ORGANIZATION_NAME.unique()

df[df.FACILITY_NAME.str.contains('Hotel')]
# Out:
#        CAPACITY                     FACILITY_NAME  OCCUPANCY OCCUPANCY_DATE  \
# 15441        60              COSTI Radisson Hotel         25     2017-05-26
# 15551        60              COSTI Radisson Hotel         25     2017-05-27
# 15661        60              COSTI Radisson Hotel         25     2017-05-28
# 15769        60              COSTI Radisson Hotel         29     2017-05-29
# 16000        60              COSTI Radisson Hotel         43     2017-05-31
# 16103        60              COSTI Radisson Hotel         56     2017-01-06
# 16212        60              COSTI Radisson Hotel         56     2017-02-06
# 16316        60              COSTI Radisson Hotel         56     2017-03-06
# 16426        60              COSTI Radisson Hotel         56     2017-04-06
# 16536       200              COSTI Radisson Hotel         57     2017-05-06
# 16645       200              COSTI Radisson Hotel         67     2017-06-06
# 16753       200              COSTI Radisson Hotel         75     2017-07-06
# 16861       200              COSTI Radisson Hotel         75     2017-08-06
# 16971       200              COSTI Radisson Hotel         75     2017-09-06
# 17074       200              COSTI Radisson Hotel         75     2017-10-06
# 17184       200              COSTI Radisson Hotel         75     2017-11-06
# 17294       200              COSTI Radisson Hotel         75     2017-12-06
# 17404       200              COSTI Radisson Hotel         75     2017-06-13
# 17514       200              COSTI Radisson Hotel         75     2017-06-14
# 17622       200              COSTI Radisson Hotel        116     2017-06-15
# 17731       200              COSTI Radisson Hotel        116     2017-06-16
# 17841       200              COSTI Radisson Hotel        116     2017-06-17
# 17949       200              COSTI Radisson Hotel        116     2017-06-18
# 18061       200              COSTI Radisson Hotel        116     2017-06-19
# 18172       200              COSTI Radisson Hotel        126     2017-06-20
# 18281       200              COSTI Radisson Hotel        126     2017-06-21
# 18388       200              COSTI Radisson Hotel        126     2017-06-22
# 18496       200              COSTI Radisson Hotel        132     2017-06-23
# 18607       200              COSTI Radisson Hotel        132     2017-06-24
# 18714       200              COSTI Radisson Hotel        132     2017-06-25
# ...         ...                               ...        ...            ...
# 35301        50        Womens Res-Alexandra Hotel         48     2019-11-25
# 35384       560  COSTI - Toronto Plaza Hotel(Fam)        512     2019-11-26
# 35385       888              COSTI Radisson Hotel        785     2019-11-26
# 35413        50        Womens Res-Alexandra Hotel         48     2019-11-26
# 35496       560  COSTI - Toronto Plaza Hotel(Fam)        521     2019-11-27
# 35497       888              COSTI Radisson Hotel        786     2019-11-27
# 35525        50        Womens Res-Alexandra Hotel         48     2019-11-27
# 35608       560  COSTI - Toronto Plaza Hotel(Fam)        521     2019-11-28
# 35609       888              COSTI Radisson Hotel        786     2019-11-28
# 35637        50        Womens Res-Alexandra Hotel         48     2019-11-28
# 35720       560  COSTI - Toronto Plaza Hotel(Fam)        521     2019-11-29
# 35721       888              COSTI Radisson Hotel        790     2019-11-29
# 35749        50        Womens Res-Alexandra Hotel         50     2019-11-29
# 35832       560  COSTI - Toronto Plaza Hotel(Fam)        521     2019-11-30
# 35861        50        Womens Res-Alexandra Hotel         49     2019-11-30
# 35944       560  COSTI - Toronto Plaza Hotel(Fam)        507     2019-12-01
# 35945       888              COSTI Radisson Hotel        772     2019-12-01
# 36057       888              COSTI Radisson Hotel        758     2019-12-02
# 36085        50        Womens Res-Alexandra Hotel         50     2019-12-02
# 36168       560  COSTI - Toronto Plaza Hotel(Fam)        509     2019-12-03
# 36169       888              COSTI Radisson Hotel        753     2019-12-03
# 36197        50        Womens Res-Alexandra Hotel         50     2019-12-03
# 36280       560  COSTI - Toronto Plaza Hotel(Fam)        528     2019-12-04
# 36281       888              COSTI Radisson Hotel        759     2019-12-04
# 36421        50        Womens Res-Alexandra Hotel         50     2019-12-05
# 36505       888              COSTI Radisson Hotel        753     2019-12-06
# 36533        50        Womens Res-Alexandra Hotel         50     2019-12-06
# 36616       560  COSTI - Toronto Plaza Hotel(Fam)        539     2019-12-07
# 36617       888              COSTI Radisson Hotel        751     2019-12-07
# 36645        50        Womens Res-Alexandra Hotel         50     2019-12-07
#
#               ORGANIZATION_NAME                            PROGRAM_NAME  \
# 15441  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 15551  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 15661  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 15769  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16000  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16103  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16212  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16316  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16426  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16536  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16645  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16753  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16861  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 16971  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17074  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17184  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17294  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17404  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17514  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17622  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17731  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17841  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 17949  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18061  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18172  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18281  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18388  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18496  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18607  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 18714  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# ...                         ...                                     ...
# 35301           City of Toronto             Women's Res-Alexandra Hotel
# 35384  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35385  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 35413           City of Toronto             Women's Res-Alexandra Hotel
# 35496  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35497  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 35525           City of Toronto             Women's Res-Alexandra Hotel
# 35608  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35609  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 35637           City of Toronto             Women's Res-Alexandra Hotel
# 35720  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35721  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 35749           City of Toronto             Women's Res-Alexandra Hotel
# 35832  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35861           City of Toronto             Women's Res-Alexandra Hotel
# 35944  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 35945  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36057  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36085           City of Toronto             Women's Res-Alexandra Hotel
# 36168  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 36169  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36197           City of Toronto             Women's Res-Alexandra Hotel
# 36280  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 36281  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36421           City of Toronto             Women's Res-Alexandra Hotel
# 36505  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36533           City of Toronto             Women's Res-Alexandra Hotel
# 36616  COSTI Immigrant Services  COSTI - Toronto Plaza Hotel (Refugees)
# 36617  COSTI Immigrant Services    COSTI Radisson Hotel Family Program.
# 36645           City of Toronto             Women's Res-Alexandra Hotel
#
#          SECTOR        SHELTER_ADDRESS SHELTER_CITY            SHELTER_NAME  \
# 15441  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 15551  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 15661  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 15769  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16000  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16103  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16212  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16316  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16426  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16536  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16645  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16753  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16861  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 16971  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17074  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17184  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17294  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17404  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17514  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17622  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17731  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17841  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 17949  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18061  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18172  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18281  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18388  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18496  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18607  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 18714  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# ...         ...                    ...          ...                     ...
# 35301     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35384  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35385  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35413     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35496  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35497  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35525     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35608  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35609  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35637     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35720  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35721  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35749     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35832  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35861     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 35944  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 35945  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36057  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36085     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 36168  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36169  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36197     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 36280  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36281  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36421     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 36505  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36533     Co-ed       674 Dundas St. W      Toronto       Women's Residence
# 36616  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36617  Families  100 Lippincott Street      Toronto  COSTI Reception Centre
# 36645     Co-ed       674 Dundas St. W      Toronto       Women's Residence
#
#       SHELTER_POSTAL_CODE SHELTER_PROVINCE  OCCUPANCY_RATE
# 15441             M5S 2P1               ON        0.416667
# 15551             M5S 2P1               ON        0.416667
# 15661             M5S 2P1               ON        0.416667
# 15769             M5S 2P1               ON        0.483333
# 16000             M5S 2P1               ON        0.716667
# 16103             M5S 2P1               ON        0.933333
# 16212             M5S 2P1               ON        0.933333
# 16316             M5S 2P1               ON        0.933333
# 16426             M5S 2P1               ON        0.933333
# 16536             M5S 2P1               ON        0.285000
# 16645             M5S 2P1               ON        0.335000
# 16753             M5S 2P1               ON        0.375000
# 16861             M5S 2P1               ON        0.375000
# 16971             M5S 2P1               ON        0.375000
# 17074             M5S 2P1               ON        0.375000
# 17184             M5S 2P1               ON        0.375000
# 17294             M5S 2P1               ON        0.375000
# 17404             M5S 2P1               ON        0.375000
# 17514             M5S 2P1               ON        0.375000
# 17622             M5S 2P1               ON        0.580000
# 17731             M5S 2P1               ON        0.580000
# 17841             M5S 2P1               ON        0.580000
# 17949             M5S 2P1               ON        0.580000
# 18061             M5S 2P1               ON        0.580000
# 18172             M5S 2P1               ON        0.630000
# 18281             M5S 2P1               ON        0.630000
# 18388             M5S 2P1               ON        0.630000
# 18496             M5S 2P1               ON        0.660000
# 18607             M5S 2P1               ON        0.660000
# 18714             M5S 2P1               ON        0.660000
# ...                   ...              ...             ...
# 35301             M5T 1H9               ON        0.960000
# 35384             M5S 2P1               ON        0.914286
# 35385             M5S 2P1               ON        0.884009
# 35413             M5T 1H9               ON        0.960000
# 35496             M5S 2P1               ON        0.930357
# 35497             M5S 2P1               ON        0.885135
# 35525             M5T 1H9               ON        0.960000
# 35608             M5S 2P1               ON        0.930357
# 35609             M5S 2P1               ON        0.885135
# 35637             M5T 1H9               ON        0.960000
# 35720             M5S 2P1               ON        0.930357
# 35721             M5S 2P1               ON        0.889640
# 35749             M5T 1H9               ON        1.000000
# 35832             M5S 2P1               ON        0.930357
# 35861             M5T 1H9               ON        0.980000
# 35944             M5S 2P1               ON        0.905357
# 35945             M5S 2P1               ON        0.869369
# 36057             M5S 2P1               ON        0.853604
# 36085             M5T 1H9               ON        1.000000
# 36168             M5S 2P1               ON        0.908929
# 36169             M5S 2P1               ON        0.847973
# 36197             M5T 1H9               ON        1.000000
# 36280             M5S 2P1               ON        0.942857
# 36281             M5S 2P1               ON        0.854730
# 36421             M5T 1H9               ON        1.000000
# 36505             M5S 2P1               ON        0.847973
# 36533             M5T 1H9               ON        1.000000
# 36616             M5S 2P1               ON        0.962500
# 36617             M5S 2P1               ON        0.845721
# 36645             M5T 1H9               ON        1.000000
#
# [2259 rows x 13 columns]

# %%
# Deciding programs and facilities to be excluded from the data
program_names_to_exclude = [
    'COSTI Reception Ctr CITY Program'
    'Christie Refugee Welcome Ctr - Settlement and Support',
    'Birkdale Residence  - Single Male Refugee Program',
    'COSTI - Quality Suites Singles Refugee Program',
    'Christe Refugee Welcome Centre - Singles',
    'Birkdale Residence  - Toronto Plaza Hotel Program (Refugees)',
    'COSTI Edward Hotel Refugee Family',
    'COSTI Edward Hotel Refugee Singles',
    'Sojourn House - Refugee Family Hotel Program-Grange',
    'COSTI - Toronto Plaza Hotel (Refugees)'
]

facility_names_to_exclude = [
    'Christie Refugee Welcome Centre',
    'HFS - Refugee Response Centre -'
]

orgnization_names_to_exclude = [
    'COSTI Immigrant Services',
    'Christie Refugee Welcome Centre, Inc.'
]

# Excluding irrelavent data

# %% [markdown]
# ---

# %% [markdown]
# ### Weather Data

# %%
# Gettting weather data
weather_2017_df = pd.read_csv('data/2017-toronto-weather.csv')
weather_2018_df = pd.read_csv('data/2018-toronto-weather.csv')
weather_2019_df = pd.read_csv('https://climate.weather.gc.ca/climate_data/bulk_data_e.html?format=csv&stationID=31688&Year=2019&timeframe=2&submit=Download+Data')
weather_df = pd.concat([weather_2017_df, weather_2018_df, weather_2019_df])

# %%
# Cleaning weather data, dropping unnecessary columns
weather_df = weather_df.drop(['Longitude (x)', 'Latitude (y)', 'Station Name', 'Climate ID', 'Data Quality',
       'Max Temp Flag', 'Min Temp Flag', 'Mean Temp Flag', 'Heat Deg Days Flag', 'Cool Deg Days Flag',
       'Total Rain Flag', 'Total Snow Flag', 'Total Precip Flag', 'Snow on Grnd (cm)',
       'Snow on Grnd Flag', 'Dir of Max Gust (10s deg)', 'Dir of Max Gust Flag', 'Spd of Max Gust (km/h)',
       'Spd of Max Gust Flag','Total Rain (mm)', 'Total Snow (cm)', 
        'Heat Deg Days (°C)', 'Cool Deg Days (°C)'], axis=1)

# %%
# Calculating the lengths of daylight each day in hours

# Coordinates of Toronto
latitude = 43.7001100
longitude = -79.4163000

# Function to calculate daylight hours in Toronto on a specific day
def get_daylight_hours(year, month, day):
    astral = Astral()
    sr, ss = astral.daylight_utc(datetime.date(year,month,day), latitude, longitude)
    return round((ss - sr).seconds / 3600, 2)

weather_df['Daylight_Hours'] = weather_df.apply(lambda df : get_daylight_hours(df.Year, df.Month, df.Day), axis=1)

# %%
# Getting the day of week of each day
weather_df['Week_Day_Int'] = weather_df.apply(lambda df : datetime.date(df.Year, df.Month, df.Day).weekday(), axis=1)

# %%
# Converting days of week to literal format
def get_week_day(week_day_int):
    week_day_dict = ['MON', 'TUE', 'WED', 'THU', 'FRI', 'SAT', 'SUN']
    return week_day_dict[week_day_int]

weather_df['Week_Day'] = weather_df.apply(lambda df: get_week_day(df.Week_Day_Int), axis=1)

# %%
# Convert date in weather data frame to datetime
weather_df['Date/Time'] = pd.to_datetime(weather_df['Date/Time'])

# %%
# Dropping unnecessary columns after daylight hours calculations
weather_df = weather_df.drop(['Year', 'Month', 'Day', 'Max Temp (°C)', 'Min Temp (°C)', 'Week_Day_Int'], axis=1)

# %%
# Changing date time column name to match shelter occupancy data column name before merging
weather_df = weather_df.rename(columns={'Date/Time': 'OCCUPANCY_DATE'})
